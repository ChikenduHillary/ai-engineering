# %%
sentence = "Her cats Name is Luna"

# %%
lowercase_sentence = sentence.lower()

# %%
print(lowercase_sentence)
# Out:
# her cats name is luna

# %%
sentence_list = [
    "Could you pass me the TV Remote",
    "it is IMPOSSIBLE to find this hotel",
    "Want to go fo dinner on Tuesday?"]

# %%
lower_sentence = [sentence.lower() for sentence in sentence_list]

# %%
print(lower_sentence)
# Out:
# ['could you pass me the tv remote', 'it is impossible to find this hotel', 'want to go fo dinner on tuesday?']
